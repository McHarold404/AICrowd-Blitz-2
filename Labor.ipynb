# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn import svm
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import confusion_matrix,classification_report
from sklearn.preprocessing import StandardScaler,LabelEncoder
from sklearn.model_selection import train_test_split
# %matplotlib inline

# %%
train_data=pd.read_csv('train.csv')
test_data=pd.read_csv('test.csv')

# %%
cross_validate=train_data.loc[25000:31997]
train_data=train_data.loc[0:25001]
train_data
# Out:
#        duration  wage-increase-first-year  wage-increase-second-year  \
# 0             3                  3.597483                   4.000000
# 1             3                  3.968619                   4.000000
# 2             2                  6.328544                   5.089680
# 3             2                  4.348288                   5.336979
# 4             2                  3.530789                   2.892247
# ...         ...                       ...                        ...
# 24997         2                  4.507784                   5.372851
# 24998         3                  5.653604                   4.000000
# 24999         2                  3.149863                   3.169706
# 25000         2                  4.372575                   4.000000
# 25001         2                  5.789343                   5.861907
#
#        wage-increase-third-year  cost-of-living-adjustment  working-hours  \
# ...

# %%
train_data.isnull().sum()
# Out:
# duration                          0
# wage-increase-first-year          0
# wage-increase-second-year         0
# wage-increase-third-year          0
# cost-of-living-adjustment         0
# working-hours                     0
# pension                           0
# standby-pay                       0
# shift-differential                0
# education-allowance               0
# statutory-holidays                0
# vacation                          0
# longterm-disability-assistance    0
# contribution-to-dental-plan       0
# bereavement-assistance            0
# contribution-to-health-plan       0
# class                             0
# dtype: int64

# %%
y_train=train_data['class']
train_data=train_data.drop(columns=['class'])
cross_validate_y=cross_validate['class']
cross_validate=cross_validate.drop(columns=['class'])

# %%
X_train,X_test,Y_train,Y_test=train_test_split(train_data,y_train,test_size=0.2,random_state=42)
#sc=StandardScaler()
#X_train=sc.fit_transform(X_train)
#X_test=sc.transform(X_test)

# %%
#Random Classifier.
#from sklearn.datasets import make_classification
#X_train,Y_train=make_classification()
rfc=RandomForestClassifier()
#rfc=svm.SVC()
rfc.fit(X_train,Y_train)
pred_rfc=rfc.predict(X_test)
pred_rfc2=rfc.predict(cross_validate)

# %%
#print(classification_report(Y_test,pred_rfc))
print(classification_report(cross_validate_y,pred_rfc2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.93      0.94      2412
#            1       0.97      0.97      0.97      4585
#
#     accuracy                           0.96      6997
#    macro avg       0.95      0.95      0.95      6997
# weighted avg       0.96      0.96      0.96      6997

# %%
submission=rfc.predict(test_data)
submission=pd.DataFrame(submission)
submission.to_csv('submission.csv',header=['class'],index=False)

# %%
#submission.count_values()
